# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("sample_data/california_housing_test.csv")
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.isnull()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df['longitude'][2] = np.nan

# %%
df.isnull().sum()
# Out:
# longitude             1
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2        NaN     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df['housing_median_age'].mean() #среднее значение
# Out:
# 28.845333333333333

# %%
df[(df["housing_median_age"] < 20) & (df["median_house_value"] > 70000)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %%
pip install jupyter
# Out:
# ...
#      -------------------------------------- 529.7/529.7 kB 2.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 121.2/121.2 kB 1.8 MB/s eta 0:00:00
# ...
#      ------------------------------------ 284.0/284.0 kB 625.0 kB/s eta 0:00:00
# ...
#      -------------------------------------- 138.3/138.3 kB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.1/2.1 MB 5.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 198.2/198.2 kB 3.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 132.2/132.2 kB 2.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 162.5/162.5 kB 3.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 133.1/133.1 kB 2.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 72.4/72.4 kB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 77.4/77.4 kB 1.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 122.5/122.5 kB 2.4 MB/s eta 0:00:00
# ...

# %%
pip install pandas
# Out:
# ...
#   WARNING: The script f2py.exe is installed in 'C:\Users\Макс\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\Макс\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 11.2/11.2 MB 5.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 502.3/502.3 kB 2.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 341.8/341.8 kB 4.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.8/14.8 MB 4.8 MB/s eta 0:00:00
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\Макс\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
